# %% [markdown]
# ### 导入相关package

# %%
import time
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 定义激活函数

# %%
def phi(x: str):
    return (1 - np.exp(-x)) / (1 + np.exp(-x))


def phi_d(x):
    return (1 - phi(x) ** 2) / 2

# %%
class LearningRule:
    error_array = []
    debug = False   # debug option

    def fit_batch(self, W, X, T, eta, n_epoch):
        pass

    def fit_sequential(self, W, X, T, eta, n_epoch):
        pass

    def predict(self, W: np.ndarray, x_test: np.ndarray):
        n = x_test.shape[1]
        x_test = np.row_stack((x_test, np.ones(n)))
        prediction = np.sign(W.dot(x_test))
        prediction = prediction[0] if prediction.shape[0] == 1 else prediction
        return prediction

    def plot_learning_curve(self):
        x = np.linspace(1, len(self.error_array) + 1, num=len(self.error_array))
        plt.title("learning curve")
        plt.xlabel("epoch")
        plt.ylabel("Mean-squared error")
        plt.plot(x, self.error_array)
        plt.show()

# %%
class PerceptronRule(LearningRule):
    W = None

    def fit_batch(self, W, X, T, eta, n_epoch):
        factor = 1 / (np.max(T) - np.min(T))

        for epoch in range(n_epoch):
            activation = W.dot(X)
            prediction = np.sign(activation)
            error = factor * (T - prediction)
            sum_error = np.linalg.norm(error, ord=1)
            delta = eta * error.dot(X.T)
            W += delta

            self.error_array.append(sum_error)
            # print(">epoch=%s, learning rate=%s, error=%.2f" % (epoch, eta, sum_error))

            if sum_error == 0.0:
                print("\nConverged in %s epoch\n" % epoch)
                break
        print("\nTraining finished in %s epoch\n" % epoch)
        self.W = W

    def fit_sequential(self, W, X, T, eta, n_epoch):
        # n samples
        n = X.shape[1]

        # the output dimensions
        out_dim = 1 if len(T.shape) == 1 else T.shape[0]

        factor = 1 / (np.max(T) - np.min(T))

        for epoch in range(n_epoch):
            sum_error = 0.0
            for i in range(n):
                for j in range(out_dim):
                    x = X.T[i]
                    activation = W[j].dot(x.T)
                    prediction = np.sign(activation)
                    error = factor * (T[j][i] - prediction)
                    delta = eta * error * x

                    # update weights successively for each pattern
                    W[j] += delta
                    sum_error += abs(error)

                    if self.debug:
                        print("x1 = %0.3f,\t x2 = %0.3f,\t activation = %0.3f, \t predict=%s, "
                              "\t target=%s, " % (x[0], x[1], activation, prediction, T[j][i]))

            # print(">epoch=%s, learning rate=%s, error=%.2f" % (epoch, eta, sum_error))

            self.error_array.append(sum_error)
            if sum_error == 0.0:
                print("\nConverged in %s epoch\n" % epoch)
                break
        print("\nTraining finished in %s epoch\n" % epoch)
        self.W = W

# %%
class DeltaRule(LearningRule):
    W = None

    def fit_batch(self, W, X, T, eta, n_epoch):
        m, n = X.shape[0], X.shape[1]
        out_dim = 1 if len(T.shape) == 1 else T.shape[0]
        threshold = n * m * out_dim * 0.005
        
        for epoch in range(n_epoch):
            delta = - eta * (W.dot(X) - T).dot(X.T)
            error = np.linalg.norm(W.dot(X) - T, ord=2)
            W += delta
            # print(">epoch=%s, learning rate=%s, error=%.2f" % (epoch, eta, error))

            self.error_array.append(error)
            if error <= threshold:
                print("\nConverged in %s epoch\n" % epoch)
                break
            elif error > np.exp(10):
                raise RuntimeError("Error becomes nan")
        print("\nTraining finished in %s epoch\n" % epoch)
        self.W = W

    def fit_sequential(self, W, X, T, eta, n_epoch):
        # m features, n samples
        m, n = X.shape[0], X.shape[1]
        out_dim = 1 if len(T.shape) == 1 else T.shape[0]
        threshold = n * m * out_dim * 0.05
        
        self.error_array = []
        for e in range(n_epoch):
            sum_error = 0.0
            for t in range(n):  # iterates over each sample
                for i in range(m):  # iterates over each feature
                    for j in range(out_dim):  # iterates over each output dimension
                        x = X.T[t]  # sample: one-by-m array
                        activation = W[j].dot(x)
                        error = T[j][t] - activation
                        delta = eta * x[i] * error
                        W[j][i] += delta
                        sum_error += 0.5 * error ** 2
            self.error_array.append(sum_error)
            # print(">epoch=%s, learning rate=%s, error=%.2f" % (e, eta, sum_error))
            if sum_error < threshold:
                print("\nConverged in %s epoch\n" % e)
                break
        print("\nTraining finished in %s epoch\n" % e)
        self.W = W

# %%
class Perceptron:
    rule_map = {'perceptron': PerceptronRule(), 'delta': DeltaRule()}

    def __init__(self, algorithm: str = 'delta', debug: bool = False):
        # learning algorithm
        if algorithm not in self.rule_map:
            raise RuntimeError("No such algorithm: %s" % algorithm)
        self.rule = self.rule_map.get(algorithm)

        # launch mode: run or debug
        self.debug = debug

        # learned weight matrix: num(output dimensions) by num(features)
        self.W = None

        # number of output dimensions
        self.dim = None

    @staticmethod
    def init_weight(n, m):
        """
        Create an initial weight matrix filled with numbers drawn from normal distribution
        :param n:
        :param m:
        :return:
        """
        return np.random.normal(loc=0, scale=1, size=(n, m))

    def fit(self, X: np.ndarray, T: np.ndarray, eta, n_epoch: int,
            mode: str = 'sequential', plot: bool = False):
        """
        Delegate the training task to the right function
        :param X: input patterns
        :param T: learning targets
        :param n_epoch: number of max epochs
        :param mode: learn samples sequentially or in batches
        :param plot: True if need to plot the data-set, false otherwise
        :return: None
        """
        # self.epoch = n_epoch

        # the output dimensions
        self.dim = 1 if len(T.shape) == 1 else T.shape[0]

        # m features, n samples
        m, n = X.shape[0], X.shape[1]

        # add ones as the bias trick
        W = self.init_weight(self.dim, m + 1)
        X = np.row_stack((X, np.ones(n)))
        T = T.reshape(self.dim, n)

        if mode == 'batch':
            self.rule.fit_batch(W, X, T, eta, n_epoch)

        elif mode == 'sequential':
            self.rule.fit_sequential(W, X, T, eta, n_epoch)

        self.W = self.rule.W
        if plot:
            self.plot_result(X, T, self.W, eta)

    def predict(self, x_test: np.ndarray):
        return self.rule.predict(self.W, x_test)

    def getWeights(self):
        return self.W[0] if self.dim == 1 else self.W

    @staticmethod
    def plot_result(X, T, W, eta):
        n = X.shape[1]

        class_0 = np.array([X.T[i] for i in range(n) if T[0][i] == -1]).T
        class_1 = np.array([X.T[i] for i in range(n) if T[0][i] == 1]).T
        plt.title("Single layer perceptron learning, eta = %s" % eta)

        # plot the two classes
        plt.scatter(class_0[0], class_0[1], edgecolors='b', marker='o')
        plt.scatter(class_1[0], class_1[1], edgecolors='r', marker='x')

        # plot the decision boundary
        x = np.linspace(min(X[0]), max(X[0]))
        for i in range(W.shape[0]):
            y = - (W[i][0] * x + W[i][2]) / W[i][1]
            plt.plot(x, y)
        plt.axis([-2, 2, -2, 2])
        plt.show()

    def plot_learning_curve(self):
        self.rule.plot_learning_curve()

# %% [markdown]
# ## 3.1 Classification with a single layer perceptron

# %% [markdown]
# ### 3.1.1 Generation of linearly-separable data

# %%
def produce_binary(n, mean_a, mean_b, cov_a, cov_b, plot: bool = False):
    """
    Produces two sets of points from multivariate normal distribution,
    and shuffle samples to get one data set

    :param n:
        The number of samples per class
    :param plot:
        True if need to plot the data-set, false otherwise
    :return:
        A data-set that contains linearly-separable data for binary classification
    """

    np.random.seed(0)
    data_a = np.random.multivariate_normal(mean_a, cov_a, n)

    np.random.seed(1)
    data_b = np.random.multivariate_normal(mean_b, cov_b, n)

    data = np.append(data_a.T, data_b.T, axis=1)

    target_a = np.linspace(-1, -1, n)
    target_b = np.ones(n)
    target = np.append(target_a, target_b)

    # shuffle the samples
    np.random.seed(2)
    permutation = np.random.permutation(data.shape[1])

    data = data[:, permutation]
    target = target[permutation]
    
    if plot:
        plt.scatter(data_a.T[0], data_a.T[1], edgecolors='b', marker='o')
        plt.scatter(data_b.T[0], data_b.T[1], edgecolors='r', marker='x')
        plt.show()

    return data, target

# %%
n = 100
mean_a = [1, 0.5]
mean_b = [-1, -3]
cov_a = [[0.5, 0], [0, 0.5]]
cov_b = cov_a
patterns, targets = produce_binary(n, mean_a, mean_b, cov_a, cov_b, plot=True)

# %% [markdown]
# ### 3.1.2 Classification with a single-layer perceptron and analysis

# %%
# Apply and compare perceptron learning with the Delta learning rule in batch mode on the generated dataset. 
# Adjust the learning rate and study the convergence of the two algorithms.

# %%
model = Perceptron(algorithm='perceptron')
model.fit(patterns, targets, eta=0.01, n_epoch=2000, mode='batch', plot=True)
model.fit(patterns, targets, eta=0.1, n_epoch=2000, mode='batch', plot=True)
model.fit(patterns, targets, eta=10, n_epoch=2000, mode='batch', plot=True)
# Out:
# Converged in 32 epoch
#
#
# Training finished in 32 epoch
# Converged in 37 epoch
#
#
# Training finished in 37 epoch
# Converged in 1 epoch
#
#
# Training finished in 1 epoch

# %%
model = Perceptron(algorithm='delta')
model.fit(patterns, targets, eta=0.0001, n_epoch=2000, mode='batch', plot=True)
model.fit(patterns, targets, eta=0.0005, n_epoch=2000, mode='batch', plot=True)
model.fit(patterns, targets, eta=0.001, n_epoch=2000, mode='batch', plot=True)
# Out:
# Training finished in 1999 epoch
# Training finished in 1999 epoch
# Training finished in 1999 epoch

# %%
# Compare sequential with a batch learning approach for the Delta rule.

# %%
model = Perceptron(algorithm='delta')
model.fit(patterns, targets, eta=0.01, n_epoch=2000, mode='sequential', plot=True)
model.plot_learning_curve()
# Out:
# Converged in 4 epoch
#
#
# Training finished in 4 epoch

# %%
model.fit(patterns, targets, eta=0.001, n_epoch=2000, mode='batch', plot=True)
model.plot_learning_curve()
# Out:
# Training finished in 1999 epoch

# %%
# Remove the bias, train your network with the Delta rule in batch mode and test its behaviour.

# %% [markdown]
# ### 3.1.3 Classification of samples that are not linearly separable

# %%
# To this end, please generate first a dataset with such property by adjusting mA, mB, sigmaA and sigmaB.

# %%
n = 100
mean_a = [0, 0.5]
mean_b = [-1, -1.5]
cov_a = [[0.5, 0], [0, 0.5]]
cov_b = cov_a

# %%
np.random.seed(0)
data_a = np.random.multivariate_normal(mean_a, cov_a, n)

np.random.seed(1)
data_b = np.random.multivariate_normal(mean_b, cov_b, n)

data_all = np.append(data_a.T, data_b.T, axis=1)
target_all = np.append(np.linspace(-1, -1, n), np.ones(n))

plt.scatter(data_a.T[0], data_a.T[1], edgecolors='b', marker='o')
plt.scatter(data_b.T[0], data_b.T[1], edgecolors='r', marker='x')
plt.show()

# %%
# 分开的classAB
ndata = 100
mA = [1.0,0.3]
sigmaA = 0.2
mB = [0.0, -0.1]
sigmaB = 0.3
data_a = np.zeros((2,ndata))
data_b = np.zeros((2,ndata))
data_a[0,50:] = np.random.normal(0,sigmaA, (1, 50)) + mA[0]
data_a[0,:50] = np.random.normal(0,sigmaA, (1, 50)) - mA[0]
data_a[1] = np.random.normal(0,sigmaA, (1, 100)) + mA[1]
data_b[0] = np.random.normal(0,sigmaB, (1, 100)) + mB[0]
data_b[1] = np.random.normal(0,sigmaB, (1, 100)) + mB[1]

data_a = data_a.T
data_b = data_b.T

data_all = np.append(data_a.T, data_b.T, axis=1)
target_all = np.append(np.linspace(-1, -1, n), np.ones(n))

plt.scatter(data_a.T[0], data_a.T[1], edgecolors='b', marker='o')
plt.scatter(data_b.T[0], data_b.T[1], edgecolors='r', marker='x')
plt.show()

# %%
def sample_binary(data_a, data_b, ratio_a, ratio_b):
    n = data_a.shape[0]
    permutation = np.random.permutation(n)
    num_a = int(n * ratio_a)
    num_b = int(n * ratio_b)
    data_a = data_a[permutation[:num_a], :]
    data_b = data_b[permutation[:num_b], :]
    data = np.append(data_a.T, data_b.T, axis=1)
    target_a = np.linspace(-1, -1, num_a)
    target_b = np.ones(num_b)
    target = np.append(target_a, target_b)
    
    np.random.seed(2)
    permutation = np.random.permutation(data.shape[1])
    data = data[:, permutation]
    target = target[permutation]
    return data, target

# %%
# 1. random 25% from each class

# %%
data, target = sample_binary(data_a, data_b, 0.75, 0.75)
model = Perceptron(algorithm='delta')
eta=0.001
model.fit(data, target, eta, n_epoch=2000, mode='batch', plot=True)
model.plot_result(data_all, target_all.reshape(1, 200), model.W, eta)
# Out:
# Training finished in 1999 epoch

# %%
# 2. random 50% from class A

# %%
data, target = sample_binary(data_a, data_b, 0.5, 1)
model = Perceptron(algorithm='delta')
eta=0.001
model.fit(data, target, eta, n_epoch=2000, mode='batch', plot=True)
model.plot_result(data_all, target_all.reshape(1, 200), model.W, eta)
# Out:
# Training finished in 1999 epoch

# %%
# 3. random 50% from classB

# %%
data, target = sample_binary(data_a, data_b, 1, 0.5)
model = Perceptron(algorithm='delta')
eta=0.001
model.fit(data, target, eta, n_epoch=2000, mode='batch', plot=True)
model.plot_result(data_all, target_all.reshape(1, 200), model.W, eta)
# Out:
# Training finished in 1999 epoch

# %%
# 4. 20% from a subset of classA for which classA(1,:)<0 
# and 80% from a subset of classA for which classA(1,:)>0

# %%
index_1, index_2 = data_a[:,0] < 0, data_a[:, 0] >= 0
data_a_left = data_a[index_1]
data_a_right = data_a[index_2]
n1, n2 = data_a_left.shape[0], data_a_right.shape[0]
permutation = np.random.permutation(n1)
data_a_left = data_a_left[permutation[:int(n1 * 0.8)]]
data_a_right = data_a_right[permutation[:int(n2 * 0.2)]]
data_a = np.append(data_a_left, data_a_right, axis=0)
data = np.append(data_a.T, data_b.T, axis=1)
target_a = np.linspace(-1, -1, data_a.shape[0])
target_b = np.ones(data_b.shape[0])
target = np.append(target_a, target_b)

# %%
model = Perceptron(algorithm='delta')
eta=0.001
model.fit(data, target, eta, n_epoch=2000, mode='batch', plot=True)
model.plot_result(data_all, target_all.reshape(1, 200), model.W, eta)
# Out:
# Training finished in 1999 epoch

# %% [markdown]
# ## 3.2 Classification and regression with a two-layer perceptron

# %%
### 3.2.1 Classification of linearly non-separable data

# %%
# 1. Modify the number of hidden nodes and demonstrate the effect 
# the size of the hidden layer has on the performance

# %%
class BackPropagation(LearningRule):
    n_hidden_nodes: int
    dim = 0      # the output dimension
    alpha = 0.9  # for momentum

    def __init__(self, n_hidden_nodes=3):
        self.n_hidden_nodes = n_hidden_nodes
        self.n_layer = 2
        self.W = None
        self.V = None
        
    def preprocess(self, X, T):
        # m features, n samples
        m, n = X.shape[0], X.shape[1]  
        dim = 1 if len(T.shape) == 1 else T.shape[0]
        # add ones as the bias trick
        X = np.row_stack((X, np.ones(n)))
        T = T.reshape(dim, n)
        return X, T
        

    def fit_batch(self, X, T, eta, n_epoch):
        X, T = self.preprocess(X, T)
        # M features, N samples
        M, N = X.shape[0], X.shape[1]
        dim = 1 if len(T.shape) == 1 else T.shape[0]
        
        W = np.random.normal(loc=0, scale=1, size=(self.n_hidden_nodes, M))
        V = np.random.normal(loc=0, scale=1, size=(dim, self.n_hidden_nodes + 1))

        alpha = self.alpha
        d_W = np.zeros(W.shape)
        d_V = np.zeros(V.shape)
        threshold = 0.001
        for epoch in range(n_epoch):
            # forward pass
            H_in = W.dot(X)
            H_out = np.row_stack((phi(H_in), np.ones(N)))

            O_in = V.dot(H_out)
            O_out = phi(O_in)

            # backward pass
            delta_o = np.multiply(O_out - T, phi_d(O_in))
            delta_h = np.multiply(V.T.dot(delta_o)[1:self.n_hidden_nodes + 1, :], phi_d(H_in))

            # weight update
            d_W = alpha * d_W - (1 - alpha) * (delta_h.dot(X.T))
            d_V = alpha * d_V - (1 - alpha) * (delta_o.dot(H_out.T))

            W += eta * d_W
            V += eta * d_V

            sum_error = 0.5 * np.linalg.norm((T - O_out), ord=2)
            self.error_array.append(sum_error)

            # print(">epoch=%s, learning rate=%s, error=%.2f" % (epoch, eta, sum_error))
            if sum_error < threshold:
                print("\nConverged in %s epoch\n" % e)
                break
        print("\nTraining finished in %s epoch\n" % epoch)
        self.W = W
        self.V = V
        self.dim = dim

    def fit_sequential(self, X, T, eta, n_epoch):
        X, T = self.preprocess(X, T)
        # M features, N samples
        M, N = X.shape[0], X.shape[1]
        dim = 1 if len(T.shape) == 1 else T.shape[0]

        W = np.random.normal(loc=0, scale=1, size=(self.n_hidden_nodes, M))
        V = np.random.normal(loc=0, scale=1, size=(dim, self.n_hidden_nodes + 1))
        H_in = np.zeros((self.n_hidden_nodes, 1))
        H_out = np.zeros((self.n_hidden_nodes + 1, 1))
        delta_h = np.zeros(H_out.shape)

        O_out = np.zeros((dim, 1))
        O_in = np.zeros(O_out.shape)
        delta_o = np.zeros(O_out.shape)

        d_W = 0.0
        d_V = 0.0
        alpha = self.alpha
        threshold = N * M * dim * 0.001
        for epoch in range(n_epoch):
            sum_error = 0.0
            for n in range(N):  # iterates over each sample
                # forward pass
                x = X.T[n]
                t = T[:, n]
                for k in range(self.n_hidden_nodes):
                    w = W[k]
                    H_in[k] = w.dot(x)
                    H_out[k] = phi(w.dot(x))
                H_out[-1][0] = 1
                for k in range(dim):
                    v = V[k]
                    O_in[k] = v.dot(H_out)
                    O_out[k] = phi(v.dot(H_out))
                    sum_error += 0.5 * (t[k] - O_out[k]) ** 2

                # backward pass
                for k in range(dim):
                    delta_o[k] = (O_out[k] - t[k]) * phi_d(O_in[k])

                for j in range(self.n_hidden_nodes):
                    delta_h[j] = (delta_o.dot(V[:, j])) * phi_d(H_in[j])

                # weight update
                for j in range(W.shape[0]):
                    for i in range(W.shape[1]):
                        d_W = alpha * d_W - (1 - alpha) * (x[i] * delta_h[j])
                        W[j][i] += eta * d_W

                for k in range(V.shape[0]):
                    for j in range(V.shape[1]):
                        d_V = alpha * d_V - (1 - alpha) * (H_out[j] * delta_o[k])
                        V[k][j] += eta * d_V

            self.error_array.append(sum_error)

            # print(">epoch=%s, learning rate=%s, error=%.2f" % (epoch, eta, sum_error))
            if sum_error < threshold:
                print("\nConverged in %s epoch\n" % epoch) 
                break
        print("\nTraining finished in %s epoch\n" % epoch)
        self.W = W
        self.V = V
        self.dim = dim

    def predict(self, X: np.ndarray):
        W, V = self.W, self.V
        X = np.row_stack((X, np.ones(X.shape[1])))
        H = phi(W.dot(X))
        H = np.row_stack((H, np.ones(H.shape[1])))
        Output = phi(V.dot(H))
        prediction = np.sign(Output)
        return prediction[0] if prediction.shape[0] == 1 else prediction
    
    def predict_value(self, X):
        W, V = self.W, self.V
        X = np.row_stack((X, np.ones(X.shape[1])))
        H = phi(W.dot(X))
        H = np.row_stack((H, np.ones(H.shape[1])))
        Output = phi(V.dot(H))
        return Output

# %%
X, T = data_all, target_all
model = BackPropagation(n_hidden_nodes=5)
eta=0.01
model.fit_sequential(X, T, eta, n_epoch=2000)
pred = model.predict(X)
accuracy = accuracy_score(T, pred)
print(accuracy)
Perceptron.plot_result(X, T.reshape(1,200), model.W, eta)
# Out:
# Training finished in 1999 epoch
#
# 0.975

# %%
# Then, formulate this problem into a more realistic assignment where only a subset of 
# data points is available for training a network

# %%
eta=0.0001
X_train, X_test, y_train, y_test = train_test_split(X.T, T, test_size=0.2, random_state=1)
X_train, X_test = X_train.T, X_test.T
model = BackPropagation(n_hidden_nodes=4)
model.fit_batch(X_train, y_train, eta, n_epoch=2000)
pred = model.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print(accuracy)
Perceptron.plot_result(X, T.reshape(1, 200), model.W, eta)
# Out:
# Training finished in 1999 epoch
#
# 0.6

# %%
# compared to different train/test split
eta=0.0001
X_train, X_test, y_train, y_test = train_test_split(X.T, T, test_size=0.5, random_state=1)
X_train, X_test = X_train.T, X_test.T
model = BackPropagation(n_hidden_nodes=4)
model.fit_batch(X_train, y_train, eta, n_epoch=2000)
pred = model.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print(accuracy)
Perceptron.plot_result(X, T.reshape(1, 200), model.W, eta)
# Out:
# Training finished in 1999 epoch
#
# 0.65

# %%
# compared to larger size of hidden layer
eta=0.0001
X_train, X_test, y_train, y_test = train_test_split(X.T, T, test_size=0.5, random_state=1)
X_train, X_test = X_train.T, X_test.T
model = BackPropagation(n_hidden_nodes=10)
model.fit_batch(X_train, y_train, eta, n_epoch=2000)
pred = model.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print(accuracy)
Perceptron.plot_result(X, T.reshape(1, 200), model.W, eta)
# Out:
# Training finished in 1999 epoch
#
# 0.64

# %%
# compared to sequential learning
eta=0.01
X_train, X_test, y_train, y_test = train_test_split(X.T, T, test_size=0.5, random_state=1)
X_train, X_test = X_train.T, X_test.T
model = BackPropagation(n_hidden_nodes=4)
model.fit_sequential(X_train, y_train, eta, n_epoch=2000)
pred = model.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print(accuracy)
Perceptron.plot_result(X, T.reshape(1, 200), model.W, eta)
# Out:
# Training finished in 1999 epoch
#
# 0.9

# %% [markdown]
# ### 3.2.2 The encoder problem

# %% [markdown]
# ### 3.2.3 Function Approximation

# %%
# 1. Generate function data

# %%
x = np.linspace(-5, 5, 21)
y = np.linspace(-5, 5, 21)
xx, yy = np.meshgrid(x, y)
zz = np.exp(-(xx ** 2 + yy ** 2)/10) - 0.5
plt.contourf(x, y, zz)
plt.show()

# %%
ndata = 21 ** 2
xx = xx.reshape(1, ndata)
yy = yy.reshape(1, ndata)
zz = zz.reshape(1, ndata)
patterns = np.append(xx, yy, axis=0)
targets = zz.reshape(1, ndata)

# %%
# 2. Train the network and visualise the approximated function

# %%
from sklearn.metrics import mean_squared_error
model = BackPropagation(n_hidden_nodes=4)
model.fit_batch(patterns, targets, eta, n_epoch=2000)
result = model.predict_value(patterns)
mse = mean_squared_error(result, targets)
print("Mean squared error: %.3f" % mse)
plt.contourf(x, y, result.reshape(21, 21))
plt.show()
# Out:
# Training finished in 1999 epoch
#
# Mean squared error: 0.003

# %%
# Please, experiment with different number of nodes in the hidden layer to 
# see how this parameter affects the final representation.

# %%
# Vary the number of nodes in the hidden layer from 1 to 25 and try to observe any trends
min_mse = 100
optimal_hidden = -1
for i in range(1, 25, 1):
    model = BackPropagation(n_hidden_nodes=i)
    model.fit_batch(patterns, targets, eta, n_epoch=2000)
    result = model.predict_value(patterns)
    mse = mean_squared_error(result, targets)
    if mse < min_mse:
        min_mse = mse
        optimal_hidden = i
    print("Mean squared error: %.5f, #hidden = %s" % (mse, i))
    plt.contourf(x, y, result.reshape(21, 21))
    plt.show()
print("Minimum mse: %s, optimal #hidden: %s" % (min_mse, optimal_hidden))
# Out:
# Training finished in 1999 epoch
#
# Mean squared error: 0.05846, #hidden = 1
# Training finished in 1999 epoch
#
# Mean squared error: 0.03875, #hidden = 2
# Training finished in 1999 epoch
#
# Mean squared error: 0.00252, #hidden = 3
# Training finished in 1999 epoch
#
# Mean squared error: 0.00236, #hidden = 4
# Training finished in 1999 epoch
#
# Mean squared error: 0.00248, #hidden = 5
# Training finished in 1999 epoch
#
# Mean squared error: 0.00221, #hidden = 6
# Training finished in 1999 epoch
#
# Mean squared error: 0.00071, #hidden = 7
# Training finished in 1999 epoch
#
# Mean squared error: 0.00037, #hidden = 8
# Training finished in 1999 epoch
#
# Mean squared error: 0.00021, #hidden = 9
# Training finished in 1999 epoch
#
# Mean squared error: 0.00030, #hidden = 10
# Training finished in 1999 epoch
#
# Mean squared error: 0.00212, #hidden = 11
# Training finished in 1999 epoch
#
# Mean squared error: 0.00120, #hidden = 12
# Training finished in 1999 epoch
#
# Mean squared error: 0.00117, #hidden = 13
# Training finished in 1999 epoch
#
# Mean squared error: 0.00086, #hidden = 14
# Training finished in 1999 epoch
#
# Mean squared error: 0.00098, #hidden = 15
# Training finished in 1999 epoch
#
# Mean squared error: 0.00047, #hidden = 16
# Training finished in 1999 epoch
#
# Mean squared error: 0.00011, #hidden = 17
# Training finished in 1999 epoch
#
# Mean squared error: 0.00013, #hidden = 18
# Training finished in 1999 epoch
#
# Mean squared error: 0.00031, #hidden = 19
# Training finished in 1999 epoch
#
# Mean squared error: 0.00009, #hidden = 20
# Training finished in 1999 epoch
#
# Mean squared error: 0.00045, #hidden = 21
# Training finished in 1999 epoch
#
# Mean squared error: 0.00012, #hidden = 22
# Training finished in 1999 epoch
#
# Mean squared error: 0.00025, #hidden = 23
# Training finished in 1999 epoch
#
# Mean squared error: 0.00095, #hidden = 24
# Minimum mse: 8.587380357844712e-05, optimal #hidden: 20

# %%
# 3. Evaluate generalisation performance

# %%
# For the selected ”best” model, run experiments with varying number of the training samples, 
# e.g. from 80% down to 20% of all the dataset.
mse_array = []
for i in np.arange(0.2, 0.8, 0.1):
    X_train, X_test, y_train, y_test = train_test_split(patterns.T, targets.T, test_size=i, random_state=1)
    X_train, X_test, y_train, y_test = X_train.T, X_test.T, y_train.T, y_test.T

    model = BackPropagation(n_hidden_nodes=20)
    model.fit_batch(X_train, y_train, eta, n_epoch=2000)
    result = model.predict_value(X_test)
    mse = mean_squared_error(result, y_test)
    mse_array.append(mse)
    print("Mean squared error: %.6f" % mse)
    plt.contourf(x, y, model.predict_value(patterns).reshape(21, 21))
    plt.show()
# Out:
# Training finished in 1999 epoch
#
# Mean squared error: 0.000280
# Training finished in 1999 epoch
#
# Mean squared error: 0.000674
# Training finished in 1999 epoch
#
# Mean squared error: 0.000336
# Training finished in 1999 epoch
#
# Mean squared error: 0.000235
# Training finished in 1999 epoch
#
# Mean squared error: 0.000864
# Training finished in 1999 epoch
#
# Mean squared error: 0.003441
# Training finished in 1999 epoch
#
# Mean squared error: 0.001454

# %%
plt.plot(np.arange(0.2, 0.8, 0.1), mse_array)
plt.xlabel("size of test set")
plt.ylabel("mean squared error")
plt.show()

# %%
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-8473cba8ff95> in <module>
# ----> 1 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# # 4 Assignment Part II

# %% [markdown]
# ## 4.1 Data

# %%
M = 1600
x = np.zeros(M)
x[0] = 1.5
for i in range(1, M):
    x[i] += 0.9 * x[i - 1]
    index = i - 25
    if index < 0: 
        continue
    else:
        x[i] += (0.2 * x[i - 25]) / (1 + np.power(x[i - 25], 10))

# %%
x=x/1.5
plt.plot(np.arange(1, M + 1, 1), x*1.5)
plt.show()

# %%
t = np.arange(301, 1501, 1)

# %%
sigma = 0.03
# 0.03, 0.09, 0.18
for i in range(800):
    x[300+i] += np.random.normal(0, sigma)

plt.plot(np.arange(0, 1200, 1), x[t]*1.5)
plt.show()

input_data = np.array([x[t - 20], x[t - 15], x[t - 10], x[t - 5], x[t]])
output = x[t + 5]

# %%
N = 1200
n_train = 800
n_test = 200
X_train, y_train = input_data[:, :n_train], output[:n_train]
X_validation, y_validation = input_data[:, n_train:N-n_test], output[n_train:N-n_test]
X_test, y_test = input_data[:, N-n_test:N], output[N-n_test:N]

# %% [markdown]
# ## 4.2 Network Configuration

# %%
class ThreeLayerPerceptron(BackPropagation):
    def fit_batch(self, X, T, sizes, eta, n_epoch, verbose=True):
        # reset the records
        self.training_error = []
        self.validation_error = []
        
        n1, n2 = sizes[0], sizes[1]
        X, T = self.preprocess(X, T)
        # M features, N samples
        M, N = X.shape[0], X.shape[1]
        dim = 1 if len(T.shape) == 1 else T.shape[0]
        
        W = np.random.normal(loc=0, scale=1, size=(n1, M))
        U = np.random.normal(loc=0, scale=1, size=(n2, n1 + 1))
        V = np.random.normal(loc=0, scale=1, size=(dim, n2 + 1))
        

        alpha = 0.9
        lambda_ = 0.25
        d_W = np.zeros(W.shape)
        d_U = np.zeros(U.shape)
        d_V = np.zeros(V.shape)
        threshold = 1e-10 * N
        if verbose: print("Converge threshold set to %s" % threshold)
        for epoch in range(n_epoch):
            # forward pass
            H_in = W.dot(X)
            H_out = np.row_stack((phi(H_in), np.ones(N)))
            
            R_in = U.dot(H_out)
            R_out = np.row_stack((phi(R_in), np.ones(N)))

            O_in = V.dot(R_out)
            O_out = phi(O_in)

            # backward pass
            delta_o = np.multiply(O_out - T, phi_d(O_in))
            delta_r = np.multiply(V.T.dot(delta_o)[1:n2+1, :], phi_d(R_in))
            delta_h = np.multiply(U.T.dot(delta_r)[1:n1+1, :], phi_d(H_in))

            # momentum and weight decay
            d_W = alpha * d_W - (1 - alpha) * (delta_h.dot(X.T) + lambda_ / (n1 * M))
            d_U = alpha * d_U - (1 - alpha) * (delta_r.dot(H_out.T) + lambda_ / (n2 * (n1 + 1)))
            d_V = alpha * d_V - (1 - alpha) * (delta_o.dot(R_out.T) + lambda_ / (1 * (n2 + 1)))
            
            # weight update
            W += eta * d_W
            U += eta * d_U
            V += eta * d_V
            self.W, self.U, self.V = W, U, V
            
            error = mean_squared_error(O_out, T) 
            self.training_error.append(error)
                
            # early stopping
            if self.early_stopping(X_validation, y_validation):
                if verbose: print("Validation error raises, perform early stopping")
                break
            
            # print(">epoch=%s, learning rate=%s, error=%.2f" % (epoch, eta, sum_error))
            if error < threshold:
                if verbose: print("\nConverged in %s epoch\n" % epoch)
                break
        
        if verbose:
            print("\nTraining finished in %s epoch with error = %s\n" % (epoch, error))
    
    def early_stopping(self, X, y):
        pred = model.predict_value(X)
        error = mean_squared_error(pred, y)
        if len(self.validation_error) != 0 and error > self.validation_error[-1]:
            return True
        self.validation_error.append(error)
        return False
    
    def predict_value(self, X):
        N = X.shape[1]
        W, U, V = self.W, self.U, self.V
        X = np.row_stack((X, np.ones(N)))
        H = np.row_stack((phi(W.dot(X)), np.ones(N)))
        R = np.row_stack((phi(U.dot(H)), np.ones(N)))
        Output = phi(V.dot(R))
        return Output.reshape(N)
    
    def plot_learning_curve(self):
        x1 = np.linspace(1, len(self.training_error) + 1, num=len(self.training_error))
        x2 = np.linspace(1, len(self.validation_error) + 1, num=len(self.validation_error))
        plt.title("learning curve")
        plt.xlabel("epoch")
        plt.ylabel("Mean-squared error")
        l1, = plt.plot(x1, self.training_error)
        l2, = plt.plot(x2, self.validation_error)
        plt.legend(handles=[l1, l2], labels=['training error', 'validation error'], loc='best')
        plt.show()

# %%
model = ThreeLayerPerceptron()
model.fit_batch(X_train, y_train, (3, 6), 1e-3, 2000)
pred = model.predict_value(X_test)
pred_validation = model.predict_value(X_validation)
model.plot_learning_curve()

error = mean_squared_error(pred*1.5, y_test*1.5)
print("Performance: [Test] mean squared error = %s" % error)
       

prediction = np.zeros(pred.shape[0]+pred_validation.shape[0])
prediction[:pred.shape[0]] = pred
prediction[-pred_validation.shape[0]:] = pred_validation
        
real = np.zeros(pred.shape[0]+pred_validation.shape[0])
real[:pred.shape[0]] = y_test
real[-pred_validation.shape[0]:] = y_validation
        
plt.plot(np.arange(prediction.shape[0]), prediction*1.5, 'b')
plt.plot(np.arange(prediction.shape[0]), real*1.5, 'r--')
plt.show()

# %% [markdown]
# ## 4.3 Simulations and evaluation

# %%
mat = np.zeros((9, 9))
for i in range(1, 9):
    for j in range(1, 9):
        model = ThreeLayerPerceptron()
        model.fit_batch(X_train, y_train, (i, j), 1e-3, 2000, verbose=False)
        pred = model.predict_value(X_test)
        error = mean_squared_error(pred, y_test)
        
        pred_validation = model.predict_value(X_validation)
        error_validation = mean_squared_error(pred_validation, y_validation)
        
        mat[i][j] = error
        
        print(i,j)
        
        prediction = np.zeros(pred.shape[0]+pred_validation.shape[0])
        prediction[:pred.shape[0]] = pred
        prediction[-pred_validation.shape[0]:] = pred_validation
        
        real = np.zeros(pred.shape[0]+pred_validation.shape[0])
        real[:pred.shape[0]] = y_test
        real[-pred_validation.shape[0]:] = y_validation
        
        plt.plot(np.arange(prediction.shape[0]), prediction*1.5, 'b')
        plt.plot(np.arange(prediction.shape[0]), real*1.5, 'r--')
        plt.show()

mat = mat[1:, 1:]

# %%
# Grid search

# %%
error_min = 1e5
error_max = -1e5
index_min = ()
index_max = ()
for i in range(0, 7):
    for j in range(0, 7):
        if mat[i][j] > error_max:
            error_max = mat[i][j]
            index_max = (i + 1, j + 1)
        if mat[i][j] < error_min:
            error_min = mat[i][j]
            index_min = (i + 1, j + 1)
print(error_min, error_max, index_min, index_max)

# %%
M = 1600
x = np.zeros(M)
x[0] = 1.5
for i in range(1, M):
    x[i] += 0.9 * x[i - 1]
    index = i - 25
    if index < 0: 
        continue
    else:
        x[i] += (0.2 * x[i - 25]) / (1 + np.power(x[i - 25], 10))

# %%
y = x

# %%
t = np.arange(301, 1501, 1)
plt.plot(np.arange(0, 1200, 1), y[t])
plt.show()

# %%
# plt.plot(np.arange(1, M + 1, 1), x)
# plt.show()


sigma = 0.09
# [0.03, 0.09, 0.18]
x = y + np.random.normal(0, sigma, y.shape)
# x = y

t = np.arange(301, 1501, 1)

plt.plot(np.arange(0, 1200, 1), x[t])
plt.show()

x = x/1.5

input_data = np.array([x[t - 20], x[t - 15], x[t - 10], x[t - 5], x[t]])
output = x[t + 5]

N = 1200
n_train = 800
n_test = 200
X_train, y_train = input_data[:, :n_train], output[:n_train]
X_validation, y_validation = input_data[:, n_train:N-n_test], output[n_train:N-n_test]
X_test, y_test = input_data[:, N-n_test:N], output[N-n_test:N]

# %%
mat = np.zeros((9, 11))
for i in range(3, 4):
    for j in range(4, 12, 2):
        model = ThreeLayerPerceptron()
        model.fit_batch(X_train, y_train, (i, j), 1e-3, 2000, verbose=False)
        pred = model.predict_value(X_test)
        error = mean_squared_error(pred*1.5, y_test*1.5)
        
        pred_validation = model.predict_value(X_validation)
        error_validation = mean_squared_error(pred_validation*1.5, y_validation*1.5)
        
        mat[i][j] = error
        
        #print(i,j)
        
        prediction = np.zeros(pred.shape[0]+pred_validation.shape[0])
        prediction[:pred.shape[0]] = pred
        prediction[-pred_validation.shape[0]:] = pred_validation
        
        real = np.zeros(pred.shape[0]+pred_validation.shape[0])
        real[:pred.shape[0]] = y_test
        real[-pred_validation.shape[0]:] = y_validation
        
        # plt.plot(np.arange(prediction.shape[0]), prediction*1.5, 'b')
        # plt.plot(np.arange(prediction.shape[0]), real*1.5, 'r--')
        # plt.show()

mat = mat[1:, 1:]

print(mat)
error_min = 1e5
error_max = -1e5
index_min = ()
index_max = ()
for i in range(0, 7):
    for j in range(0, 7):
        if mat[i][j] > error_max:
            error_max = mat[i][j]
            index_max = (i + 1, j + 1)
        if mat[i][j] < error_min:
            error_min = mat[i][j]
            index_min = (i + 1, j + 1)
print(error_min, error_max, index_min, index_max)
